# %% [markdown]
# ## RNN for Sentiment Analysis
# ## A stacked Long-Short Term Memory (LSTM) RNN for Sentiment Analysis on IMDB dataset

# %%
import os
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %%
tf.random.set_seed(22)
np.random.seed(22)
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
assert tf.__version__.startswith('2.')

# %%
# fix random seed for reproducibility
np.random.seed(7)
# load the dataset but only keep the top n words, zero the rest
top_words = 10000
# truncate and pad input sequences
max_review_length = 80
(X_train, y_train), (X_test, y_test) = keras.datasets.imdb.load_data(num_words=top_words)
# X_train = tf.convert_to_tensor(X_train)
# y_train = tf.one_hot(y_train, depth=2)
print('Pad sequences (samples x time)')
x_train = keras.preprocessing.sequence.pad_sequences(X_train, maxlen=max_review_length)
x_test = keras.preprocessing.sequence.pad_sequences(X_test, maxlen=max_review_length)
print('x_train shape:', x_train.shape)
print('x_test shape:', x_test.shape)
# Out:
# Pad sequences (samples x time)
# x_train shape: (25000, 80)
# x_test shape: (25000, 80)

# %%
class RNN(keras.Model):

    def __init__(self, units, num_classes, num_layers):
        super(RNN, self).__init__()
        
        self.rnn = keras.layers.LSTM(units, return_sequences=True)
        self.rnn2 = keras.layers.LSTM(units)

        # self.cells = (keras.layers.LSTMCell(units) for _ in range(num_layers))
        # self.rnn = keras.layers.RNN(self.cells, return_sequences=True, return_state=True)
        # self.rnn = keras.layers.LSTM(units, unroll=True)
        # self.rnn = keras.layers.StackedRNNCells(self.cells)

        # have 1000 words totally, every word will be embedding into 100 length vector
        # the max sentence length is 80 words
        self.embedding = keras.layers.Embedding(top_words, 100, input_length=max_review_length)
        self.fc = keras.layers.Dense(1)

    def call(self, inputs, training=None, mask=None):

        # print('x', inputs.shape)
        # [b, sentence len] => [b, sentence len, word embedding]
        x = self.embedding(inputs)
        # print('embedding', x.shape)
        x = self.rnn(x) 
        x = self.rnn2(x) 
        # print('rnn', x.shape)

        x = self.fc(x)
        print(x.shape)

        return x

# %%
def main():

    units = 64
    num_classes = 2
    batch_size = 32
    epochs = 20

    model = RNN(units, num_classes, num_layers=2)
    model.compile(optimizer=keras.optimizers.Adam(0.001),
                  loss=keras.losses.BinaryCrossentropy(from_logits=True),
                  metrics=['accuracy'])
    # train
    model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs,
              validation_data=(x_test, y_test), verbose=1)

    # evaluate on test set
    scores = model.evaluate(x_test, y_test, batch_size, verbose=1)
    print("Final test loss and accuracy :", scores)

# %%
if __name__ == '__main__':
    main()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1009 16:17:20.116902 4554544576 deprecation.py:323] From /anaconda3/lib/python3.6/site-packages/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# (None, 1)
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
# (None, 1)
# (None, 1)
# 24992/25000 [============================>.] - ETA: 0s - loss: 0.4208 - accuracy: 0.7933(None, 1)
# 25000/25000 [==============================] - 85s 3ms/sample - loss: 0.4209 - accuracy: 0.7932 - val_loss: 0.3735 - val_accuracy: 0.8202
# Epoch 2/20
# 25000/25000 [==============================] - 79s 3ms/sample - loss: 0.2774 - accuracy: 0.8816 - val_loss: 0.3649 - val_accuracy: 0.8379
# Epoch 3/20
# 25000/25000 [==============================] - 74s 3ms/sample - loss: 0.1949 - accuracy: 0.9213 - val_loss: 0.4539 - val_accuracy: 0.8292
# Epoch 4/20
# 25000/25000 [==============================] - 73s 3ms/sample - loss: 0.1317 - accuracy: 0.9477 - val_loss: 0.4900 - val_accuracy: 0.8291
# Epoch 5/20
# 25000/25000 [==============================] - 71s 3ms/sample - loss: 0.0909 - accuracy: 0.9667 - val_loss: 0.5938 - val_accuracy: 0.8106
# Epoch 6/20
# 25000/25000 [==============================] - 71s 3ms/sample - loss: 0.0674 - accuracy: 0.9764 - val_loss: 0.6339 - val_accuracy: 0.8182
# Epoch 7/20
# 25000/25000 [==============================] - 71s 3ms/sample - loss: 0.0464 - accuracy: 0.9852 - val_loss: 0.7729 - val_accuracy: 0.8232
# Epoch 8/20
# 25000/25000 [==============================] - 80s 3ms/sample - loss: 0.0335 - accuracy: 0.9891 - val_loss: 0.7832 - val_accuracy: 0.8013
# Epoch 9/20
# 25000/25000 [==============================] - 85s 3ms/sample - loss: 0.0374 - accuracy: 0.9869 - val_loss: 0.7816 - val_accuracy: 0.8241
# Epoch 10/20
# 25000/25000 [==============================] - 86s 3ms/sample - loss: 0.0287 - accuracy: 0.9910 - val_loss: 0.8649 - val_accuracy: 0.8139
# Epoch 11/20
# 25000/25000 [==============================] - 74s 3ms/sample - loss: 0.0205 - accuracy: 0.9935 - val_loss: 0.9510 - val_accuracy: 0.8152
# Epoch 12/20
# 25000/25000 [==============================] - 71s 3ms/sample - loss: 0.0188 - accuracy: 0.9942 - val_loss: 0.9548 - val_accuracy: 0.8146
# Epoch 13/20
# 25000/25000 [==============================] - 73s 3ms/sample - loss: 0.0151 - accuracy: 0.9950 - val_loss: 1.0443 - val_accuracy: 0.8212
# Epoch 14/20
# 25000/25000 [==============================] - 70s 3ms/sample - loss: 0.0126 - accuracy: 0.9963 - val_loss: 0.9699 - val_accuracy: 0.8138
# Epoch 15/20
# 25000/25000 [==============================] - 74s 3ms/sample - loss: 0.0125 - accuracy: 0.9957 - val_loss: 0.9600 - val_accuracy: 0.8130
# Epoch 16/20
# 25000/25000 [==============================] - 78s 3ms/sample - loss: 0.0151 - accuracy: 0.9952 - val_loss: 1.0290 - val_accuracy: 0.8138
# Epoch 17/20
# 25000/25000 [==============================] - 74s 3ms/sample - loss: 0.0132 - accuracy: 0.9962 - val_loss: 0.9887 - val_accuracy: 0.8161
# Epoch 18/20
# 25000/25000 [==============================] - 79s 3ms/sample - loss: 0.0107 - accuracy: 0.9969 - val_loss: 1.0046 - val_accuracy: 0.8165
# Epoch 19/20
# 25000/25000 [==============================] - 80s 3ms/sample - loss: 0.0078 - accuracy: 0.9974 - val_loss: 1.2184 - val_accuracy: 0.8177
# Epoch 20/20
# 25000/25000 [==============================] - 83s 3ms/sample - loss: 0.0075 - accuracy: 0.9980 - val_loss: 1.0566 - val_accuracy: 0.8139
# 25000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
